# %%
import os
import json
import uuid
import subprocess

import pandas as pd
# Out:
# /tmp/ipykernel_57033/2457369407.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Mount the GPCRmd directory with:
#
# `sshfs aperalta@gwaihir.prib.upf.edu:/data/GPCRmd/ /home/alex/sshfs_mountpoints/gpcrmd/`
#
# Mount verde home with:
#
# `sshfs aperalta@verde.prib.upf.edu:/home/aperalta/ /home/alex/sshfs_mountpoints/verde`

# %%
# Paths to run locally.

PROJECT_ROOT = "/home/alex/Documents/pocket_tool"
GPCRMD_ROOT = "/home/alex/sshfs_mountpoints/gpcrmd/media"
ALIGNED_POCKETS_DIR = "/home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets"
# pocket_dir = "/home/alex/Desktop/mdpocket_oversized_mount/"

COMPL_INFO_PATH = os.path.join(GPCRMD_ROOT, "files/Precomputed/compl_info.json")

RESULTS_DIR = os.path.join(PROJECT_ROOT, "results/06_gpcrmd_crystals_overlap/output")
REFERENCE_GPCR = os.path.join(PROJECT_ROOT, "data/ref_gpcr/data/a2a_6gdg_opm_rotated.pdb")
CHIMERA = "/home/alex/.local/UCSF-Chimera64-1.17.3/bin/chimera"
TMP_DIR = "/home/alex/Desktop"
PDB_DIR = os.path.join(PROJECT_ROOT, "data/pdbs/data")

# %%
def read_dynids():
    dynids_path = os.path.join(PROJECT_ROOT, "data/working_sims/data/dynids.csv")
    with open(dynids_path, 'r') as file:
        dynids = file.read().splitlines()
    return dynids


def read_trajids():
    trajids_path = os.path.join(PROJECT_ROOT, "data/working_sims/data/trajids.csv")
    with open(trajids_path, 'r') as file:
        trajids = file.read().splitlines()
    return trajids


def read_tm_allosteric_modulators():
    tm_mods_path = os.path.join(PROJECT_ROOT, "data/tm_allosteric_modulators_list/data/tm_allosteric_modulators.csv")
    return pd.read_csv(tm_mods_path, sep=';')


def read_json_into_dict(json_path):
    """
    Reads a JSON file and returns the data as a dictionary.
    """
    with open(json_path, 'r') as f:
        data = json.load(f)
    return data


def correct_wrong_uniprot_names_complinfo(uniprot_name):
    """
    Corrects the UniProt names by replacing underscores with hyphens and converting to lowercase.
    """
    if uniprot_name == "pd2r2_human":
        return "pd2r_human"
    else:
        return uniprot_name
    

# TODO IMPORTANT: If I want this to work properly, I have to align to the TM region.
def chimera_align(target_pdb):
    """
    """
    # Construct aligned PDB path.
    aligned_pdb_basename = os.path.basename(target_pdb).replace(".pdb", "_all_aligned.pdb")
    aligned_pdb_path = f'{RESULTS_DIR}/aligned_pdbs/{aligned_pdb_basename}'
    
    if os.path.exists(aligned_pdb_path):
        # print(f"Aligned PDB already exists: {aligned_pdb_path}")
        return aligned_pdb_path

    chimera_script = (
        f'open {REFERENCE_GPCR}; '                    # Model #0
        f'open {target_pdb}; '                        # Model #1
        f'mm #1 #0:; '  # Align model #1 to #0
        f'select #1; write selected relative 0 #1 {aligned_pdb_path};' # Save aligned target GPCR
    )

    # Writing and executing the chimera align script.
    tmp_script = os.path.join(
        TMP_DIR, f'tmp_chimera_script_{str(uuid.uuid4())}')
    with open(tmp_script, "w") as fh:
        print(chimera_script, file=fh)

    result = subprocess.run(
        [CHIMERA, '--nogui', f'cmd:{tmp_script}'], 
        stdout=subprocess.PIPE,  # Capture standard output
        text=True                # Decode output as string
    )

    # # Extract the RMSD value from the Chimera output.
    # terminal_output = result.stdout
    # for line in terminal_output.split("\n"):
    #     if line.startswith("RMSD between"):
    #         rmsd = line.split("pairs: ")[1].strip(")")
    
    # Clean up the temporary files.
    os.remove(tmp_script)

    return aligned_pdb_path


def get_trajetory_ids_from_dynid(dynid, compl_info):
    """
    Retrieves trajectory IDs associated with a given dynamic ID.
    """
    trajids = []
    traj_files = compl_info['dyn'+str(dynid)]['traj_f']
    for file in traj_files:
        basename = os.path.basename(file)
        trajid = basename.split("_")[0]
        trajids.append(trajid)
    return trajids


def create_pymol_startup_line(pdbs):
    """
    Creates a PyMOL startup line for the given PDB files.
    """
    return ("pymol " + " ".join([os.path.join(ALIGNED_POCKETS_DIR, pdb) for pdb in pdbs]))

# %%
# Loading stuff
allosteric_df = read_tm_allosteric_modulators()
dynids = read_dynids()
trajids = read_trajids()
compl_info = read_json_into_dict(COMPL_INFO_PATH)

# %%
for allosteric_df_entry in allosteric_df.itertuples():
    uniprot_name = allosteric_df_entry.uniprot_name.strip().lower()
    pdb_code = allosteric_df_entry.pdb.strip().lower()

    dynds_and_trajids = []
    for dynid_key in compl_info:

        # Ignore if fields not correctly completed
        if not compl_info[dynid_key]['up_name']:
            continue

        dynid = dynid_key.strip('dyn')
        compl_uniprot_name = compl_info[dynid_key]['up_name'].strip().lower()
        compl_uniprot_name = correct_wrong_uniprot_names_complinfo(compl_uniprot_name)
        compl_pdb_code = compl_info[dynid_key]['pdb_id'].strip().lower()

        # Check the uniprot names match
        if compl_uniprot_name != uniprot_name:
            continue

        # Check if it's apoform
        if compl_info[dynid_key]["lig_lname"] != False:
            continue

        # Don't compare the PDB with self simulation
        if pdb_code == compl_pdb_code:
            continue

        # Check the dynID is on our working list of dynids
        if dynid not in dynids:
            continue

        trajids = get_trajetory_ids_from_dynid(dynid, compl_info)
        dynds_and_trajids.append((dynid, trajids))

    if dynds_and_trajids:
        print(f"Processing {uniprot_name} ({pdb_code}) with dynids and trajids: {dynds_and_trajids}")
        aligned_pdb = chimera_align(target_pdb=os.path.join(PDB_DIR, f'{pdb_code}.pdb'))

        aligned_files = [aligned_pdb]
        for dynid, trajids in dynds_and_trajids:
            for trajid in trajids:
                aligned_pocket_file = f"dyn{dynid}_traj{trajid}_pocket*tmaligned.pdb"
                aligned_files.append(aligned_pocket_file)
        print(create_pymol_startup_line(aligned_files), end="\n\n")
# Out:
# Processing adrb2_human (6n48) with dynids and trajids: [('751', ['15441', '15442', '15443']), ('769', ['15567', '15568', '15569']), ('763', ['15525', '15526', '15527']), ('829', ['15972', '15973', '15974']), ('863', ['16210', '16211', '16212']), ('962', ['16872', '16873', '16874']), ('970', ['16923', '16924', '16925']), ('951', ['16795', '16796', '16797']), ('926', ['16630', '16631', '16632']), ('979', ['16976', '16977', '16978']), ('1003', ['17144', '17145', '17146']), ('11', ['10185', '10186', '10187']), ('100', ['10953', '10954', '10955']), ('96', ['10916', '10917', '10918']), ('107', ['11015', '11016', '11017']), ('113', ['11073', '11074', '11075']), ('82', ['10799', '10800', '10801']), ('65', ['10647', '10648', '10649']), ('114', ['11085', '11086', '11087']), ('159', ['11490', '11491', '11492']), ('88', ['10850', '10851', '10852']), ('116', ['11105', '11106', '11107'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6n48_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15441_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15442_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15443_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15567_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15568_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15569_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15525_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15526_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15527_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15972_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15973_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15974_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16210_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16211_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16212_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16872_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16873_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16923_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16924_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16925_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16795_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16796_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16797_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16630_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16631_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16632_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16976_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16977_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16978_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn1003_traj17144_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn1003_traj17145_pocket*tmaligned.pdb /home/alex/ ...
#
# Processing adrb2_human (6oba) with dynids and trajids: [('751', ['15441', '15442', '15443']), ('769', ['15567', '15568', '15569']), ('763', ['15525', '15526', '15527']), ('829', ['15972', '15973', '15974']), ('863', ['16210', '16211', '16212']), ('962', ['16872', '16873', '16874']), ('970', ['16923', '16924', '16925']), ('951', ['16795', '16796', '16797']), ('926', ['16630', '16631', '16632']), ('979', ['16976', '16977', '16978']), ('11', ['10185', '10186', '10187']), ('100', ['10953', '10954', '10955']), ('96', ['10916', '10917', '10918']), ('107', ['11015', '11016', '11017']), ('113', ['11073', '11074', '11075']), ('82', ['10799', '10800', '10801']), ('65', ['10647', '10648', '10649']), ('114', ['11085', '11086', '11087']), ('159', ['11490', '11491', '11492']), ('88', ['10850', '10851', '10852']), ('116', ['11105', '11106', '11107'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6oba_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15441_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15442_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn751_traj15443_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15567_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15568_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn769_traj15569_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15525_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15526_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn763_traj15527_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15972_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15973_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn829_traj15974_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16210_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16211_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn863_traj16212_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16872_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16873_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn962_traj16874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16923_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16924_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn970_traj16925_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16795_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16796_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn951_traj16797_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16630_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16631_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn926_traj16632_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16976_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16977_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn979_traj16978_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn11_traj10185_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn11_traj10186_pocket*tmaligned.pdb /home/alex/sshf ...
#
# Processing c5ar1_human (6c1q) with dynids and trajids: [('920', ['16588', '16589', '16590'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6c1q_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16588_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16589_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16590_pocket*tmaligned.pdb
#
# Processing c5ar1_human (6c1r) with dynids and trajids: [('920', ['16588', '16589', '16590'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6c1r_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16588_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16589_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn920_traj16590_pocket*tmaligned.pdb
#
# Processing cnr1_human (6kqi) with dynids and trajids: [('163', ['11516', '11517', '11518']), ('162', ['11508', '11509', '11510']), ('852', ['16133', '16134', '16135']), ('896', ['16421', '16422', '16423'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6kqi_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn163_traj11516_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn163_traj11517_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn163_traj11518_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn162_traj11508_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn162_traj11509_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn162_traj11510_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn852_traj16133_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn852_traj16134_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn852_traj16135_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn896_traj16421_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn896_traj16422_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn896_traj16423_pocket*tmaligned.pdb
#
# Processing ffar1_human (5kw2) with dynids and trajids: [('75', ['10731', '10732', '10733']), ('793', ['15725', '15726', '15727']), ('928', ['16644', '16645', '16646'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5kw2_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10731_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10732_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10733_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15725_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15726_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15727_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16644_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16645_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16646_pocket*tmaligned.pdb
#
# Processing ffar1_human (5tzr) with dynids and trajids: [('75', ['10731', '10732', '10733']), ('765', ['15539', '15540', '15541']), ('928', ['16644', '16645', '16646'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5tzr_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10731_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10732_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10733_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15539_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15540_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15541_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16644_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16645_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16646_pocket*tmaligned.pdb
#
# Processing ffar1_human (4phu) with dynids and trajids: [('75', ['10731', '10732', '10733']), ('765', ['15539', '15540', '15541']), ('793', ['15725', '15726', '15727']), ('928', ['16644', '16645', '16646'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/4phu_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10731_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10732_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn75_traj10733_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15539_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15540_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn765_traj15541_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15725_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15726_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn793_traj15727_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16644_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16645_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn928_traj16646_pocket*tmaligned.pdb
#
# Processing glr_human (5ee7) with dynids and trajids: [('110', ['11048', '11049', '11050']), ('742', ['15380', '15381', '15382'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5ee7_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11048_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11049_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11050_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15380_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15381_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15382_pocket*tmaligned.pdb
#
# Processing glr_human (5xez) with dynids and trajids: [('110', ['11048', '11049', '11050']), ('742', ['15380', '15381', '15382']), ('815', ['15874', '15875', '15876'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5xez_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11048_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11049_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11050_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15380_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15381_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15382_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15875_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15876_pocket*tmaligned.pdb
#
# Processing glr_human (5xf1) with dynids and trajids: [('110', ['11048', '11049', '11050']), ('742', ['15380', '15381', '15382']), ('815', ['15874', '15875', '15876'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5xf1_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11048_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11049_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11050_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15380_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15381_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15382_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15875_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15876_pocket*tmaligned.pdb
#
# Processing glp1r_human (6ln2) with dynids and trajids: [('710', ['15152', '15153', '15154']), ('746', ['15408', '15409', '15410']), ('876', ['16291', '16292', '16293']), ('704', ['15110', '15111', '15112']), ('698', ['15072', '15073', '15074'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6ln2_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15152_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15153_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15154_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15408_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15409_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15410_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16291_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16292_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16293_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15110_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15111_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15112_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15072_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15073_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15074_pocket*tmaligned.pdb
#
# Processing glp1r_human (6kk1) with dynids and trajids: [('710', ['15152', '15153', '15154']), ('746', ['15408', '15409', '15410']), ('876', ['16291', '16292', '16293']), ('698', ['15072', '15073', '15074'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6kk1_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15152_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15153_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15154_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15408_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15409_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15410_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16291_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16292_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16293_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15072_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15073_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15074_pocket*tmaligned.pdb
#
# Processing glp1r_human (6kjv) with dynids and trajids: [('710', ['15152', '15153', '15154']), ('876', ['16291', '16292', '16293']), ('704', ['15110', '15111', '15112']), ('698', ['15072', '15073', '15074'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6kjv_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15152_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15153_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15154_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16291_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16292_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16293_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15110_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15111_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15112_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15072_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15073_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15074_pocket*tmaligned.pdb
#
# Processing glp1r_human (6kk7) with dynids and trajids: [('710', ['15152', '15153', '15154']), ('746', ['15408', '15409', '15410']), ('704', ['15110', '15111', '15112']), ('698', ['15072', '15073', '15074'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/6kk7_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15152_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15153_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15154_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15408_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15409_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15410_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15110_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15111_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15112_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15072_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15073_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15074_pocket*tmaligned.pdb
#
# Processing glp1r_human (5vew) with dynids and trajids: [('710', ['15152', '15153', '15154']), ('746', ['15408', '15409', '15410']), ('876', ['16291', '16292', '16293']), ('704', ['15110', '15111', '15112'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5vew_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15152_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15153_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn710_traj15154_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15408_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15409_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15410_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16291_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16292_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16293_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15110_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15111_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15112_pocket*tmaligned.pdb
#
# Processing glp1r_human (5vex) with dynids and trajids: [('746', ['15408', '15409', '15410']), ('876', ['16291', '16292', '16293']), ('704', ['15110', '15111', '15112']), ('698', ['15072', '15073', '15074'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5vex_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15408_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15409_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn746_traj15410_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16291_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16292_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn876_traj16293_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15110_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15111_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn704_traj15112_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15072_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15073_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn698_traj15074_pocket*tmaligned.pdb
#
# Processing glr_human (5xf1) with dynids and trajids: [('110', ['11048', '11049', '11050']), ('742', ['15380', '15381', '15382']), ('815', ['15874', '15875', '15876'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5xf1_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11048_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11049_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11050_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15380_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15381_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15382_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15875_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15876_pocket*tmaligned.pdb
#
# Processing glr_human (5xez) with dynids and trajids: [('110', ['11048', '11049', '11050']), ('742', ['15380', '15381', '15382']), ('815', ['15874', '15875', '15876'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5xez_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11048_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11049_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn110_traj11050_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15380_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15381_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn742_traj15382_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15874_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15875_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn815_traj15876_pocket*tmaligned.pdb
#
# Processing p2ry1_human (4xnv) with dynids and trajids: [('179', ['11677', '11678', '11679']), ('180', ['11684', '11685', '11686'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/4xnv_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn179_traj11677_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn179_traj11678_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn179_traj11679_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn180_traj11684_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn180_traj11685_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn180_traj11686_pocket*tmaligned.pdb
#
# Processing par2_human (5ndz) with dynids and trajids: [('977', ['16962', '16963', '16964'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/5ndz_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn977_traj16962_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn977_traj16963_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn977_traj16964_pocket*tmaligned.pdb
#
# Processing pd2r_human (8xxv) with dynids and trajids: [('884', ['16337', '16338', '16339']), ('984', ['17011', '17012', '17013'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/8xxv_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16337_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16338_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16339_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17011_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17012_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17013_pocket*tmaligned.pdb
#
# Processing pd2r_human (8xxu) with dynids and trajids: [('884', ['16337', '16338', '16339']), ('984', ['17011', '17012', '17013'])]
# pymol /home/alex/Documents/pocket_tool/results/06_gpcrmd_crystals_overlap/output/aligned_pdbs/8xxu_all_aligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16337_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16338_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn884_traj16339_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17011_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17012_pocket*tmaligned.pdb /home/alex/sshfs_mountpoints/verde/combine_pockets/results/aligned/aligned_pockets/dyn984_traj17013_pocket*tmaligned.pdb
