# %%
import pandas as pd
# Out:
# /tmp/ipykernel_14547/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
csv_path = "/home/alex/sshfs_mountpoints/verde/Documents/pocket_tool/src/08_novel_structure_analysis/rmsd_comparison_novel_pocket.csv"

# %%
df = pd.read_csv(csv_path)
df.head()
# Out:
#     state replicate  frame      rmsd
# 0  active     rep_1      0  2.924088
# 1  active     rep_1      1  3.155045
# 2  active     rep_1      2  2.834194
# 3  active     rep_1      3  2.786832
# 4  active     rep_1      4  2.844464

# %%
df.sort_values(by=['rmsd'], inplace=True, ascending=True)
df[0:50]
# Out:
#        state replicate  frame      rmsd
# 6167  active     rep_2   1167  2.484967
# 6381  active     rep_2   1381  2.524944
# 6339  active     rep_2   1339  2.557279
# 6010  active     rep_2   1010  2.592913
# 6304  active     rep_2   1304  2.596735
# 5176  active     rep_2    176  2.598051
# 137   active     rep_1    137  2.601832
# 6183  active     rep_2   1183  2.609956
# 6295  active     rep_2   1295  2.615894
# 6014  active     rep_2   1014  2.616744
# 5315  active     rep_2    315  2.616859
# 6244  active     rep_2   1244  2.616954
# 6283  active     rep_2   1283  2.620382
# 6316  active     rep_2   1316  2.624556
# 5370  active     rep_2    370  2.628068
# 6005  active     rep_2   1005  2.628974
# 5816  active     rep_2    816  2.629739
# 5831  active     rep_2    831  2.630598
# 6189  active     rep_2   1189  2.630845
# 6305  active     rep_2   1305  2.632475
# 5389  active     rep_2    389  2.632684
# 118   active     rep_1    118  2.634313
# ...
